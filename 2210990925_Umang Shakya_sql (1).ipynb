# %%
import mysql.connector as sql
import pandas as pd

db_connection = sql.connect(host='localhost', database='data', user='root', password='root')
query = "select * from salaries"
df_mysql = pd.read_sql(query, con = db_connection)
df_mysql
# Out:
# C:\Users\udaib\AppData\Local\Temp\ipykernel_14464\1602222169.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_mysql = pd.read_sql(query, con = db_connection)
#             Id         EmployeeName  \
# 0            1       NATHANIEL FORD
# 1            2         GARY JIMENEZ
# 2            3       ALBERT PARDINI
# 3            4    CHRISTOPHER CHONG
# 4            5      PATRICK GARDNER
# ...        ...                  ...
# 109715  110282  Leah A Fraimow-Wong
# 109716  110285         Mo Sze  Wong
# 109717  110286      Teagan J Mucher
# 109718  110287  Heather  Stephenson
# 109719  110288      Jon N Johannsen
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# ...

# %% [markdown]
# # DISPLAY TOP 5 ROWS OF THE DATASET

# %%
df_mysql.head(5)
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25           567595.43         567595.43
# 1  155966.02    245131.88  137811.38           538909.28         538909.28
# 2  212739.13    106088.18   16452.60           335279.91         335279.91
# 3   77916.00     56120.71  198306.90           332343.61         332343.61
# 4  134401.60      9737.00  182234.59           326373.19         326373.19
#
#    Year Notes         Agency Status
# 0  2011        San Francisco
# ...

# %% [markdown]
# # CHECK LAST 3 ROWS OF THE DATASET

# %%
df_mysql.tail(3)
# Out:
#             Id         EmployeeName                    JobTitle  BasePay  \
# 109717  110286      Teagan J Mucher      Public Service Trainee   332.33
# 109718  110287  Heather  Stephenson  BdComm Mbr, Grp2,M=$25/Mtg   275.00
# 109719  110288      Jon N Johannsen           Stage Electrician   334.60
#
#         OvertimePay  OtherPay Benefits  TotalPay  TotalPayBenefits  Year  \
# 109717          0.0      3.81     3.37    336.14            339.51  2013
# 109718          0.0      0.00    64.31    275.00            339.31  2013
# 109719          0.0      0.00     3.35    334.60            337.95  2013
#
#        Notes         Agency Status
# 109717        San Francisco
# 109718        San Francisco
# 109719        San Francisco

# %% [markdown]
# # FIND SHAPE OF OUR DATASET(NUMBER OF ROWS & NUMBER OF COLUMNS)

# %%
print("columns: ",df_mysql.shape[1])
print("rows: ",df_mysql.shape[0])
# Out:
# columns:  13
# rows:  109720

# %% [markdown]
# # GET INFORMATION ABOUT OUR DATASET LIKE TOTAL NUMBER ROWS,TOTAL NUMBER OF COLUMNS,DATATYPE OF EACH COLUMN AND MEMORY REQUIREMENT

# %%
df_mysql.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109720 entries, 0 to 109719
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                109720 non-null  int64
#  1   EmployeeName      109720 non-null  object
#  2   JobTitle          109720 non-null  object
#  3   BasePay           109720 non-null  float64
#  4   OvertimePay       109720 non-null  float64
#  5   OtherPay          109720 non-null  float64
#  6   Benefits          109720 non-null  object
#  7   TotalPay          109720 non-null  float64
#  8   TotalPayBenefits  109720 non-null  float64
#  9   Year              109720 non-null  int64
#  10  Notes             109720 non-null  object
#  11  Agency            109720 non-null  object
#  12  Status            109720 non-null  object
# dtypes: float64(5), int64(2), object(6)
# memory usage: 10.9+ MB

# %%
import mysql.connector as sql
import pandas as pd

db_connection = sql.connect(host='localhost', database='data', user='root', password='root')
query = "select * from train"
df_train = pd.read_sql(query, con = db_connection)
df_train
# Out:
# C:\Users\udaib\AppData\Local\Temp\ipykernel_14464\151357160.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_train = pd.read_sql(query, con = db_connection)
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 709          886         0       3
# 710          887         0       2
# 711          888         1       1
# 712          890         1       1
# 713          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# ...

# %% [markdown]
# # GET OVERALL STATISTICS ABOUT THE DATAFRAME

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   714.000000  714.000000  714.000000  714.000000  714.000000
# mean    448.582633    0.406162    2.236695   29.712885    0.512605
# std     259.119524    0.491460    0.838250   14.529273    0.929783
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     222.250000    0.000000    1.000000   20.250000    0.000000
# 50%     445.000000    0.000000    2.000000   28.000000    0.000000
# 75%     677.750000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    5.000000
#
#             Parch        Fare
# count  714.000000  714.000000
# mean     0.431373   34.694514
# std      0.853289   52.918930
# min      0.000000    0.000000
# 25%      0.000000    8.050000
# 50%      0.000000   15.741700
# 75%      1.000000   33.375000
# max      6.000000  512.329200

# %% [markdown]
# # DATA FILTERING

# %%
df_train.filter(["Survived"])
# Out:
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 709         0
# 710         0
# 711         1
# 712         1
# 713         0
#
# [714 rows x 1 columns]

# %% [markdown]
# # CHECK NULL VALUES IN THE DATASET

# %%
df_train.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 709        False     False   False  False  False  False  False  False   False
# 710        False     False   False  False  False  False  False  False   False
# 711        False     False   False  False  False  False  False  False   False
# 712        False     False   False  False  False  False  False  False   False
# 713        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %% [markdown]
# # DROP THE COLUMN

# %%
df_train.drop(columns=["SibSp"])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 709          886         0       3
# 710          887         0       2
# 711          888         1       1
# 712          890         1       1
# 713          891         0       3
#
#                                                   Name     Sex  Age  Parch  \
# 0                              Braund, Mr. Owen Harris    male   22      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      0
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      0
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %% [markdown]
# # HANDLE MISSING VALUES

# %%
missing_values = df_train.isnull().sum()
print("Missing values:\n", missing_values)
# Out:
# Missing values:
#  PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# # CATEGORICAL DATA ENCODING

# %% [markdown]
# # WHAT IS UNIVARIATE ANALYSIS

# %%
import pandas as pd
df = pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # HOW MANY PEOPLE SURVIVED AND HOW MANY DIED PLOT ON GRAPH

# %%
import matplotlib.pyplot as plt
import numpy as np
import mysql.connector as sql
import pandas as pd

db_connection = sql.connect(host='localhost', database='data', user='root', password='root')
query = "select * from train"
df_train = pd.read_sql(query, con = db_connection)


survive = len(df_train[df_train["Survived"]==1])
nsurvive = len(df_train[df_train["Survived"]==0])
x = ['survived','not survived']
y = np.array([survive, nsurvive])

fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.axis('equal')
ax.pie(y, labels=x,autopct='%1.2f%%')
plt.show()
# Out:
# C:\Users\udaib\AppData\Local\Temp\ipykernel_5376\4244237511.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_train = pd.read_sql(query, con = db_connection)

# %% [markdown]
# # HOW MANY PASSENGERS WERE IN FIRST CLASS,SECOND CLASS AND THIRD CLASS PLOT THOSE FIGURES ON GRAPH

# %%
import matplotlib.pyplot as plt
import numpy as np
import mysql.connector as sql
import pandas as pd

db_connection = sql.connect(host='localhost', database='data', user='root', password='root')
query = "select * from train"
df_train = pd.read_sql(query, con = db_connection)


class_1 = len(df_train[df_train["Pclass"]==1])
class_2 = len(df_train[df_train["Pclass"]==2])
class_3 = len(df_train[df_train["Pclass"]==3])
x = ['first class','second class','third class']
y = np.array([class_1,class_2,class_3])

fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.axis('equal')
ax.pie(y, labels=x,autopct='%1.2f%%')
plt.show()
# Out:
# C:\Users\udaib\AppData\Local\Temp\ipykernel_5376\677882463.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_train = pd.read_sql(query, con = db_connection)

# %% [markdown]
# # NUMBER  OF MALE AND FEMALE PASSANGERS

# %%
print("males: ",len(df_train[df_train["Sex"]=="male"]))
print("females: ",len(df_train[df_train["Sex"]=="female"]))
# Out:
# males:  453
# females:  261

# %% [markdown]
# # BIVARIANT ANALYSIS

# %%
df_train.columns
plt.figure(figsize=(8, 6))
plt.scatter(data['PassengerId'], data['Age'], color='blue', alpha=0.7)
plt.xlabel('Variable 1')
plt.ylabel('Variable 2')
plt.title('Scatter Plot of Variable 1 vs Variable 2')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 df_train.columns
# ----> 2 plt.figure(figsize=(8, 6))
#       3 plt.scatter(data['PassengerId'], data['Age'], color='blue', alpha=0.7)
#       4 plt.xlabel('Variable 1')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # WHO HAS BETTER CHANCE OF SURVIVAL MALE OR FEMALE

# %% [markdown]
# # WHICH PASSENGER CLASS HAS BETTER CHANCE OF SURVIVAL(FIRST,SECOND,OR THIRD CLASS)?

# %% [markdown]
# # FEATURE ENGINEERING
